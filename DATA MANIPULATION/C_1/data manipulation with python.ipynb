# %%
import pandas as pd
homelessness=pd.read_csv('F:\DATACAMP\DATA MANIPULATION\C_1\homelessness.csv')
homelessness.values
# Out:
# array([[0, 'East South Central', 'Alabama', 2570.0, 864.0, 4887681],
#        [1, 'Pacific', 'Alaska', 1434.0, 582.0, 735139],
#        [2, 'Mountain', 'Arizona', 7259.0, 2606.0, 7158024],
#        [3, 'West South Central', 'Arkansas', 2280.0, 432.0, 3009733],
#        [4, 'Pacific', 'California', 109008.0, 20964.0, 39461588],
#        [5, 'Mountain', 'Colorado', 7607.0, 3250.0, 5691287],
#        [6, 'New England', 'Connecticut', 2280.0, 1696.0, 3571520],
#        [7, 'South Atlantic', 'Delaware', 708.0, 374.0, 965479],
#        [8, 'South Atlantic', 'District of Columbia', 3770.0, 3134.0,
#         701547],
#        [9, 'South Atlantic', 'Florida', 21443.0, 9587.0, 21244317],
#        [10, 'South Atlantic', 'Georgia', 6943.0, 2556.0, 10511131],
#        [11, 'Pacific', 'Hawaii', 4131.0, 2399.0, 1420593],
#        [12, 'Mountain', 'Idaho', 1297.0, 715.0, 1750536],
#        [13, 'East North Central', 'Illinois', 6752.0, 3891.0, 12723071],
# ...

# %%
homelessness.sort_values(['family_members','state_pop'], ascending=[False,False]).head()
# Out:
#     Unnamed: 0              region          state  individuals  \
# 32          32        Mid-Atlantic       New York      39827.0
# 4            4             Pacific     California     109008.0
# 21          21         New England  Massachusetts       6811.0
# 9            9      South Atlantic        Florida      21443.0
# 43          43  West South Central          Texas      19199.0
#
#     family_members  state_pop
# 32         52070.0   19530351
# 4          20964.0   39461588
# 21         13257.0    6882635
# 9           9587.0   21244317
# 43          6111.0   28628666

# %%
scolumns=homelessness[['state','region']]
scolumns.head()
# Out:
#         state              region
# 0     Alabama  East South Central
# 1      Alaska             Pacific
# 2     Arizona            Mountain
# 3    Arkansas  West South Central
# 4  California             Pacific

# %%
subrows=homelessness[homelessness['state'].isin(['Alaska'])] #put []in .isin() method during subsetting rows
subrows
# Out:
#    Unnamed: 0   region   state  individuals  family_members  state_pop
# 1           1  Pacific  Alaska       1434.0           582.0     735139

# %%
# how to create a new column

homelessness['total']=homelessness['individuals']+homelessness['family_members']
homelessness.head()
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#    state_pop     total
# 0    4887681    3434.0
# 1     735139    2016.0
# 2    7158024    9865.0
# 3    3009733    2712.0
# 4   39461588  129972.0

# %% [markdown]
# # CHAPTER 2

# %%
sales=pd.read_csv('F:\DATACAMP\DATA MANIPULATION\C_1\sales_subset.csv')
sales.head()
# Out:
#    Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0           0      1    A           1  2010-02-05      24924.50       False
# 1           1      1    A           1  2010-03-05      21827.90       False
# 2           2      1    A           1  2010-04-02      57258.43       False
# 3           3      1    A           1  2010-05-07      17413.94       False
# 4           4      1    A           1  2010-06-04      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0       5.727778              0.679451         8.106
# 1       8.055556              0.693452         8.106
# 2      16.816667              0.718284         7.808
# 3      22.527778              0.748928         7.808
# 4      27.050000              0.714586         7.808

# %%
sales.shape
# Out:
# (10774, 10)

# %%
sales['type'].value_counts(normalize=True)
# Out:
# type
# A    0.91628
# B    0.08372
# Name: proportion, dtype: float64

# %%
sales.head()
# Out:
#    Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0           0      1    A           1  2010-02-05      24924.50       False
# 1           1      1    A           1  2010-03-05      21827.90       False
# 2           2      1    A           1  2010-04-02      57258.43       False
# 3           3      1    A           1  2010-05-07      17413.94       False
# 4           4      1    A           1  2010-06-04      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0       5.727778              0.679451         8.106
# 1       8.055556              0.693452         8.106
# 2      16.816667              0.718284         7.808
# 3      22.527778              0.748928         7.808
# 4      27.050000              0.714586         7.808

# %%
print(sales["weekly_sales"].mean())
print(sales["weekly_sales"].median())
# Out:
# 23843.95014850566
# 12049.064999999999

# %%
#finding the oldest and latest dates

oldest_date=sales['date'].max()
recent_date=sales['date'].min()
print(oldest_date)
print(recent_date)
# Out:
# 2012-10-26
# 2010-02-05

# %%
import numpy as np
mean=sales['weekly_sales'].agg('mean')
median=sales['weekly_sales'].agg('median')
print('mean:',mean)
print('median:', median)

def iqr(column):
    return column.quantile(.75)- column.quantile(.25)

print(sales[["weekly_sales","temperature_c"]].agg([iqr, np.median]))
# Out:
# mean: 23843.95014850566
# median: 12049.064999999999
#         weekly_sales  temperature_c
# iqr        28482.735      16.583333
# median     12049.065      16.966667

# %%
sales_subset=sales[(sales['department']==1) & (sales['store']==1)]

# %%
sales_subset['date'].sort_values()

sales_subset['cum_sum']=sales_subset['weekly_sales'].cumsum()
sales_subset['cum_max']=sales_subset['weekly_sales'].cummax()

print(sales_subset[['date','cum_sum', 'cum_max']])
# Out:
#           date    cum_sum   cum_max
# 0   2010-02-05   24924.50  24924.50
# 1   2010-03-05   46752.40  24924.50
# 2   2010-04-02  104010.83  57258.43
# 3   2010-05-07  121424.77  57258.43
# 4   2010-06-04  138982.86  57258.43
# 5   2010-07-02  155316.00  57258.43
# 6   2010-08-06  172824.41  57258.43
# 7   2010-09-03  189066.19  57258.43
# 8   2010-10-01  209160.38  57258.43
# 9   2010-11-05  243399.26  57258.43
# 10  2010-12-03  265916.82  57258.43
# 11  2011-01-07  281901.06  57258.43
# C:\Users\finac\AppData\Local\Temp\ipykernel_20224\2273666251.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_subset['cum_sum']=sales_subset['weekly_sales'].cumsum()
# ...

# %%
store_types=sales.drop_duplicates(subset=["store","type"])
print(store_types.head())
store_department=sales.drop_duplicates(subset=["store","department"])
print(store_department.head())
# Out:
#       Unnamed: 0  store type  department        date  weekly_sales  \
# 0              0      1    A           1  2010-02-05      24924.50
# 901          901      2    A           1  2010-02-05      35034.06
# 1798        1798      4    A           1  2010-02-05      38724.42
# 2699        2699      6    A           1  2010-02-05      25619.00
# 3593        3593     10    B           1  2010-02-05      40212.84
#
#       is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 0          False       5.727778              0.679451         8.106
# 901        False       4.550000              0.679451         8.324
# 1798       False       6.533333              0.686319         8.623
# 2699       False       4.683333              0.679451         7.259
# 3593       False      12.411111              0.782478         9.765
#     Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0            0      1    A           1  2010-02-05      24924.50       False
# ...

# %%
holyday_dates=sales[sales['is_holiday']]
display(holyday_dates.head())
display(holyday_dates.shape)
# Out:
#       Unnamed: 0  store type  department        date  weekly_sales  \
# 498          498      1    A          45  2010-09-10         11.47
# 691          691      1    A          77  2011-11-25       1431.00
# 896          896      1    A          99  2011-11-25       2400.00
# 1532        1532      2    A          60  2010-09-10          8.80
# 1587        1587      2    A          77  2011-11-25       1431.00
#
#       is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 498         True      25.938889              0.677602         7.787
# 691         True      15.633333              0.854861         7.866
# 896         True      15.633333              0.854861         7.866
# 1532        True      26.161111              0.677602         8.099
# 1587        True      13.533333              0.854861         7.441
# (42, 10)

# %%
holyday_dates=sales[sales['is_holiday']].drop_duplicates(subset='date')
display(holyday_dates.head())
display(holyday_dates.shape)
# Out:
#       Unnamed: 0  store type  department        date  weekly_sales  \
# 498          498      1    A          45  2010-09-10         11.47
# 691          691      1    A          77  2011-11-25       1431.00
# 2315        2315      4    A          47  2010-02-12        498.00
# 6735        6735     19    A          39  2012-09-07         13.41
# 6810        6810     19    A          47  2010-12-31       -449.00
#
#       is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 498         True      25.938889              0.677602         7.787
# 691         True      15.633333              0.854861         7.866
# 2315        True      -1.755556              0.679715         8.623
# 6735        True      22.333333              1.076766         8.193
# 6810        True      -1.861111              0.881278         8.067
# (7, 10)

# %%
holyday_dates['date']
# Out:
# 498     2010-09-10
# 691     2011-11-25
# 2315    2010-02-12
# 6735    2012-09-07
# 6810    2010-12-31
# 6815    2012-02-10
# 6820    2011-09-09
# Name: date, dtype: object

# %%
store_types['type'].value_counts()
store_types['type'].value_counts(normalize=True)
# Out:
# type
# A    0.916667
# B    0.083333
# Name: proportion, dtype: float64

# %%
store_department['department'].value_counts(sort='ascending')
# Out:
# department
# 1     12
# 55    12
# 72    12
# 71    12
# 67    12
#       ..
# 37    10
# 48     8
# 50     6
# 39     4
# 43     2
# Name: count, Length: 80, dtype: int64

# %%
store_department['department'].value_counts(normalize=True)
# Out:
# department
# 1     0.012917
# 55    0.012917
# 72    0.012917
# 71    0.012917
# 67    0.012917
#         ...
# 37    0.010764
# 48    0.008611
# 50    0.006459
# 39    0.004306
# 43    0.002153
# Name: proportion, Length: 80, dtype: float64

# %%
total_weekly_sales=sales['weekly_sales'].sum()
print(total_weekly_sales)

type_A_sales=sales[sales['type']=='A']['weekly_sales'].sum()
print(type_A_sales)

type_B_sales=sales[sales['type']=='B']['weekly_sales'].sum()
print(type_B_sales)

type_C_sales=sales[sales['type']=='C']['weekly_sales'].sum()
print(type_C_sales)

totalsalesprop_bytype=[type_A_sales, type_B_sales,type_C_sales]/total_weekly_sales
display(totalsalesprop_bytype)
# Out:
# 256894718.89999998
# 233716315.01
# 23178403.89
# 0.0
# array([0.9097747, 0.0902253, 0.       ])

# %%
total_weekly_sales
sales.groupby(['type','is_holiday'])['weekly_sales'].agg(sum)
# Out:
# type  is_holiday
# A     False         2.336927e+08
#       True          2.360181e+04
# B     False         2.317678e+07
#       True          1.621410e+03
# Name: weekly_sales, dtype: float64

# %%
import numpy as np
by_type=sales.groupby('type')['weekly_sales'].agg([np.min, np.max, np.mean,np.median])
display(by_type)

unemployment_fuelprice=sales.groupby('type') [['unemployment','fuel_price_usd_per_l']].agg([np.min, np.max, np.mean,np.median])
display(unemployment_fuelprice)
# Out:
#          min        max          mean    median
# type
# A    -1098.0  293966.05  23674.667242  11943.92
# B     -798.0  232558.51  25696.678370  13336.08
#      unemployment                         fuel_price_usd_per_l            \
#               min    max      mean median                  min       max
# type
# A           3.879  8.992  7.972611  8.067             0.664129  1.107410
# B           7.170  9.765  9.279323  9.199             0.760023  1.107674
#
#
#           mean    median
# type
# A     0.744619  0.735455
# B     0.805858  0.803348

# %%
import pandas as pd
sales.pivot_table(columns='is_holiday', index='type',values=['weekly_sales'], aggfunc=[ np.mean,np.median])
# Out:
#                     mean                  median
#             weekly_sales            weekly_sales
# is_holiday         False      True         False    True
# type
# A           23768.583523  590.04525    12028.955   37.500
# B           25751.980533  810.70500    13348.680  810.705

# %%
department_type_pivot= sales.pivot_table(index='department', columns= 'type', values='weekly_sales', aggfunc=[np.mean], fill_value=0, margins=True)
display(department_type_pivot)
# https://campus.datacamp.com/courses/data-manipulation-with-pandas/aggregating-dataframes?ex=15 see the link and submit the answer
# Out:
#                     mean
# type                   A              B           All
# department
# 1           30961.725379   44050.626667  32052.467153
# 2           67600.158788  112958.526667  71380.022778
# 3           17160.002955   30580.655000  18278.390625
# 4           44285.399091   51219.654167  44863.253681
# 5           34821.011364   63236.875000  37189.000000
# ...                  ...            ...           ...
# 96          21367.042857    9528.538333  20337.607681
# 97          28471.266970    5828.873333  26584.400833
# 98          12875.423182     217.428333  11820.590278
# 99            379.123659       0.000000    379.123659
# All         23674.667242   25696.678370  23843.950149
#
# [81 rows x 3 columns]

# %% [markdown]
#  # CHAPTER 3

# %%
import pandas as pd
temparatures=pd.read_csv('F:/DATACAMP/DATA MANIPULATION/C_1/temperatures.csv')
temparatures.head()
# Out:
#    Unnamed: 0        date     city        country  avg_temp_c
# 0           0  2000-01-01  Abidjan  Côte D'Ivoire      27.293
# 1           1  2000-02-01  Abidjan  Côte D'Ivoire      27.685
# 2           2  2000-03-01  Abidjan  Côte D'Ivoire      29.061
# 3           3  2000-04-01  Abidjan  Côte D'Ivoire      28.162
# 4           4  2000-05-01  Abidjan  Côte D'Ivoire      27.547

# %%
temparatures_ind=temparatures.set_index('city')
temparatures_ind.head()
# Out:
#          Unnamed: 0        date        country  avg_temp_c
# city
# Abidjan           0  2000-01-01  Côte D'Ivoire      27.293
# Abidjan           1  2000-02-01  Côte D'Ivoire      27.685
# Abidjan           2  2000-03-01  Côte D'Ivoire      29.061
# Abidjan           3  2000-04-01  Côte D'Ivoire      28.162
# Abidjan           4  2000-05-01  Côte D'Ivoire      27.547

# %%
index_reset=temparatures_ind.reset_index('city', drop=True)
index_reset.head()
# Out:
#    Unnamed: 0        date        country  avg_temp_c
# 0           0  2000-01-01  Côte D'Ivoire      27.293
# 1           1  2000-02-01  Côte D'Ivoire      27.685
# 2           2  2000-03-01  Côte D'Ivoire      29.061
# 3           3  2000-04-01  Côte D'Ivoire      28.162
# 4           4  2000-05-01  Côte D'Ivoire      27.547

# %%
#"Moscow" and "Saint Petersburg
city_list=['Moscow','Saint Petersburg']
city_filter=temparatures_ind.loc[city_list]
city_filter.head()
# Out:
#         Unnamed: 0        date country  avg_temp_c
# city
# Moscow       10725  2000-01-01  Russia      -7.313
# Moscow       10726  2000-02-01  Russia      -3.551
# Moscow       10727  2000-03-01  Russia      -1.661
# Moscow       10728  2000-04-01  Russia      10.096
# Moscow       10729  2000-05-01  Russia      10.357

# %%
#"Brazil"/"Rio De Janeiro" and "Pakistan"/"Lahore", assigning to rows_to_keep.
multi_index=temparatures.set_index(['country','city'])
multi_index
# Out:
#                        Unnamed: 0        date  avg_temp_c
# country       city
# Côte D'Ivoire Abidjan           0  2000-01-01      27.293
#               Abidjan           1  2000-02-01      27.685
#               Abidjan           2  2000-03-01      29.061
#               Abidjan           3  2000-04-01      28.162
#               Abidjan           4  2000-05-01      27.547
# ...                           ...         ...         ...
# China         Xian          16495  2013-05-01      18.979
#               Xian          16496  2013-06-01      23.522
#               Xian          16497  2013-07-01      25.251
#               Xian          16498  2013-08-01      24.528
#               Xian          16499  2013-09-01         NaN
#
# [16500 rows x 3 columns]

# %%
row_to_keep=[('Brazil','Rio De Janeiro'),('Pakistan','Lahore')]
filter_list=multi_index.loc[row_to_keep]
filter_list
# Out:
#                          Unnamed: 0        date  avg_temp_c
# country  city
# Brazil   Rio De Janeiro       12540  2000-01-01      25.974
#          Rio De Janeiro       12541  2000-02-01      26.699
#          Rio De Janeiro       12542  2000-03-01      26.270
#          Rio De Janeiro       12543  2000-04-01      25.750
#          Rio De Janeiro       12544  2000-05-01      24.356
# ...                             ...         ...         ...
# Pakistan Lahore                8575  2013-05-01      33.457
#          Lahore                8576  2013-06-01      34.456
#          Lahore                8577  2013-07-01      33.279
#          Lahore                8578  2013-08-01      31.511
#          Lahore                8579  2013-09-01         NaN
#
# [330 rows x 3 columns]

# %%
first=multi_index.sort_index()
display(first)

second=multi_index.sort_index(level='city')
display(second)

three=multi_index.sort_index(level=['country','city'] , ascending=[True, False])
display(three)
# Out:
#                     Unnamed: 0        date  avg_temp_c
# country     city
# Afghanistan Kabul         7260  2000-01-01       3.326
#             Kabul         7261  2000-02-01       3.454
#             Kabul         7262  2000-03-01       9.612
#             Kabul         7263  2000-04-01      17.925
#             Kabul         7264  2000-05-01      24.658
# ...                        ...         ...         ...
# Zimbabwe    Harare        5605  2013-05-01      18.298
#             Harare        5606  2013-06-01      17.020
#             Harare        5607  2013-07-01      16.299
#             Harare        5608  2013-08-01      19.232
#             Harare        5609  2013-09-01         NaN
#
# [16500 rows x 3 columns]
#                        Unnamed: 0        date  avg_temp_c
# country       city
# Côte D'Ivoire Abidjan           0  2000-01-01      27.293
#               Abidjan           1  2000-02-01      27.685
#               Abidjan           2  2000-03-01      29.061
# ...

# %% [markdown]
# # Slicing index values
# Slicing lets you select consecutive elements of an object using first:last syntax.
# \
# DataFrames can be sliced by index values or by row/column number; we'll start with the first case. This involves slicing inside the .loc[] method.
#
# Compared to slicing lists, there are a few things to remember.
#
# You can only slice an index if the index is sorted (using .sort_index()).
# \
# To slice at the outer level, first and last can be strings.
# \
# To slice at inner levels, first and last should be tuples.
# \
# If you pass a single slice to .loc[], it will slice the rows.

# %%
pak_russ=three.loc['Pakistan':'Russia']
pak_russ
# Out:
#                  Unnamed: 0        date  avg_temp_c
# country  city
# Pakistan Lahore        8415  2000-01-01      12.792
#          Lahore        8416  2000-02-01      14.339
#          Lahore        8417  2000-03-01      20.309
#          Lahore        8418  2000-04-01      29.072
#          Lahore        8419  2000-05-01      34.845
# ...                     ...         ...         ...
# Russia   Moscow       10885  2013-05-01      16.152
#          Moscow       10886  2013-06-01      18.718
#          Moscow       10887  2013-07-01      18.136
#          Moscow       10888  2013-08-01      17.485
#          Moscow       10889  2013-09-01         NaN
#
# [1155 rows x 3 columns]

# %%
# multi index have to be sorted otherwise it won't work

li=multi_index.sort_index(level=['country','city'] , ascending=[True, True])

full_slice=li.loc[("Pakistan","Lahore"):("Russia","Moscow")]
full_slice
# Out:
#                  Unnamed: 0        date  avg_temp_c
# country  city
# Pakistan Lahore        8415  2000-01-01      12.792
#          Lahore        8416  2000-02-01      14.339
#          Lahore        8417  2000-03-01      20.309
#          Lahore        8418  2000-04-01      29.072
#          Lahore        8419  2000-05-01      34.845
# ...                     ...         ...         ...
# Russia   Moscow       10885  2013-05-01      16.152
#          Moscow       10886  2013-06-01      18.718
#          Moscow       10887  2013-07-01      18.136
#          Moscow       10888  2013-08-01      17.485
#          Moscow       10889  2013-09-01         NaN
#
# [660 rows x 3 columns]

# %%
li=multi_index.sort_index(level=['country','city'] , ascending=[True, True])

full_slice=li.loc[("India","Hyderabad"):("Iraq","Baghdad"),('date','avg_temp_c')]
full_slice
# Out:
#                          date  avg_temp_c
# country city
# India   Hyderabad  2000-01-01      23.779
#         Hyderabad  2000-02-01      25.826
#         Hyderabad  2000-03-01      28.821
#         Hyderabad  2000-04-01      32.698
#         Hyderabad  2000-05-01      32.438
# ...                       ...         ...
# Iraq    Baghdad    2013-05-01      28.673
#         Baghdad    2013-06-01      33.803
#         Baghdad    2013-07-01      36.392
#         Baghdad    2013-08-01      35.463
#         Baghdad    2013-09-01         NaN
#
# [2145 rows x 2 columns]

# %%
temparatures_new=temparatures.loc[:,'date':'avg_temp_c']
temparatures_new
# Out:
#              date     city        country  avg_temp_c
# 0      2000-01-01  Abidjan  Côte D'Ivoire      27.293
# 1      2000-02-01  Abidjan  Côte D'Ivoire      27.685
# 2      2000-03-01  Abidjan  Côte D'Ivoire      29.061
# 3      2000-04-01  Abidjan  Côte D'Ivoire      28.162
# 4      2000-05-01  Abidjan  Côte D'Ivoire      27.547
# ...           ...      ...            ...         ...
# 16495  2013-05-01     Xian          China      18.979
# 16496  2013-06-01     Xian          China      23.522
# 16497  2013-07-01     Xian          China      25.251
# 16498  2013-08-01     Xian          China      24.528
# 16499  2013-09-01     Xian          China         NaN
#
# [16500 rows x 4 columns]

# %%
subset_by_date=temparatures_new[(temparatures_new["date"]>="2010-01-01") & (temparatures_new["date"]<="2011-12-31")]
subset_by_date
# Out:
#              date     city        country  avg_temp_c
# 120    2010-01-01  Abidjan  Côte D'Ivoire      28.270
# 121    2010-02-01  Abidjan  Côte D'Ivoire      29.262
# 122    2010-03-01  Abidjan  Côte D'Ivoire      29.596
# 123    2010-04-01  Abidjan  Côte D'Ivoire      29.068
# 124    2010-05-01  Abidjan  Côte D'Ivoire      28.258
# ...           ...      ...            ...         ...
# 16474  2011-08-01     Xian          China      23.069
# 16475  2011-09-01     Xian          China      16.775
# 16476  2011-10-01     Xian          China      12.587
# 16477  2011-11-01     Xian          China       7.543
# 16478  2011-12-01     Xian          China      -0.490
#
# [2400 rows x 4 columns]

# %%
subset_new=temparatures_new.set_index('date').sort_index()
display(subset_new)

display(subset_new.loc['2010': '2012'])
display(subset_new.loc['2010-08': '2011-03'])
# Out:
#                  city        country  avg_temp_c
# date
# 2000-01-01    Abidjan  Côte D'Ivoire      27.293
# 2000-01-01     Lahore       Pakistan      12.792
# 2000-01-01   Tangshan          China      -5.406
# 2000-01-01      Gizeh          Egypt      12.669
# 2000-01-01    Lakhnau          India      15.152
# ...               ...            ...         ...
# 2013-09-01    Nanjing          China         NaN
# 2013-09-01  New Delhi          India         NaN
# 2013-09-01   New York  United States      17.408
# 2013-09-01     Peking          China         NaN
# 2013-09-01       Xian          China         NaN
#
# [16500 rows x 3 columns]
#                   city    country  avg_temp_c
# date
# 2010-01-01  Faisalabad   Pakistan      11.810
# 2010-01-01   Melbourne  Australia      20.016
# 2010-01-01   Chongqing      China       7.921
# 2010-01-01   São Paulo     Brazil      23.738
# 2010-01-01   Guangzhou      China      14.136
# ...                ...        ...         ...
# ...

# %%
display(subset_new.loc['2010': '2012'])
# Out:
#                   city    country  avg_temp_c
# date
# 2010-01-01  Faisalabad   Pakistan      11.810
# 2010-01-01   Melbourne  Australia      20.016
# 2010-01-01   Chongqing      China       7.921
# 2010-01-01   São Paulo     Brazil      23.738
# 2010-01-01   Guangzhou      China      14.136
# ...                ...        ...         ...
# 2011-12-01      Nagoya      Japan       6.476
# 2011-12-01   Hyderabad      India      23.613
# 2011-12-01        Cali   Colombia      21.559
# 2011-12-01        Lima       Peru      18.293
# 2011-12-01     Bangkok   Thailand      25.021
#
# [2400 rows x 3 columns]

# %%
display(subset_new.loc['2010-08': '2011-03'])
# Out:
#                 city        country  avg_temp_c
# date
# 2010-08-01  Calcutta          India      30.226
# 2010-08-01      Pune          India      24.941
# 2010-08-01     Izmir         Turkey      28.352
# 2010-08-01   Tianjin          China      25.543
# 2010-08-01    Manila    Philippines      27.101
# ...              ...            ...         ...
# 2011-02-01     Kabul    Afghanistan       3.914
# 2011-02-01   Chicago  United States       0.276
# 2011-02-01    Aleppo          Syria       8.246
# 2011-02-01     Delhi          India      18.136
# 2011-02-01   Rangoon          Burma      26.631
#
# [700 rows x 3 columns]

# %%
temparatures['date'].dtypes
# Out:
# dtype('O')

# %%
temparatures['date']=pd.to_datetime(temparatures['date'], format= 'ISO8601')
temparatures['year']=temparatures['date'].dt.year
temparatures
# Out:
#        Unnamed: 0       date     city        country  avg_temp_c  year
# 0               0 2000-01-01  Abidjan  Côte D'Ivoire      27.293  2000
# 1               1 2000-02-01  Abidjan  Côte D'Ivoire      27.685  2000
# 2               2 2000-03-01  Abidjan  Côte D'Ivoire      29.061  2000
# 3               3 2000-04-01  Abidjan  Côte D'Ivoire      28.162  2000
# 4               4 2000-05-01  Abidjan  Côte D'Ivoire      27.547  2000
# ...           ...        ...      ...            ...         ...   ...
# 16495       16495 2013-05-01     Xian          China      18.979  2013
# 16496       16496 2013-06-01     Xian          China      23.522  2013
# 16497       16497 2013-07-01     Xian          China      25.251  2013
# 16498       16498 2013-08-01     Xian          China      24.528  2013
# 16499       16499 2013-09-01     Xian          China         NaN  2013
#
# [16500 rows x 6 columns]

# %%
pivoit_by_year=temparatures.pivot_table(index=['country','city'], columns='year', values='avg_temp_c')
pivoit_by_year
# Out:
# year                                 2000       2001       2002       2003  \
# country       city
# Afghanistan   Kabul             15.822667  15.847917  15.714583  15.132583
# Angola        Luanda            24.410333  24.427083  24.790917  24.867167
# Australia     Melbourne         14.320083  14.180000  14.075833  13.985583
#               Sydney            17.567417  17.854500  17.733833  17.592333
# Bangladesh    Dhaka             25.905250  25.931250  26.095000  25.927417
# ...                                   ...        ...        ...        ...
# United States Chicago           11.089667  11.703083  11.532083  10.481583
#               Los Angeles       16.643333  16.466250  16.430250  16.944667
#               New York           9.969083  10.931000  11.252167   9.836000
# Vietnam       Ho Chi Minh City  27.588917  27.831750  28.064750  27.827667
# Zimbabwe      Harare            20.283667  20.861000  21.079333  20.889167
#
# ...

# %%
pivoit_by_year.loc['Egypt':'India']
# Out:
# year                       2000       2001       2002       2003       2004  \
# country  city
# Egypt    Alexandria   20.744500  21.454583  21.456167  21.221417  21.064167
#          Cairo        21.486167  22.330833  22.414083  22.170500  22.081917
#          Gizeh        21.486167  22.330833  22.414083  22.170500  22.081917
# Ethiopia Addis Abeba  18.241250  18.296417  18.469750  18.320917  18.292750
# France   Paris        11.739667  11.371250  11.871333  11.909500  11.338833
# Germany  Berlin       10.963667   9.690250  10.264417  10.065750   9.822583
# India    Ahmadabad    27.436000  27.198083  27.719083  27.403833  27.628333
#          Bangalore    25.337917  25.528167  25.755333  25.924750  25.252083
#          Bombay       27.203667  27.243667  27.628667  27.578417  27.318750
#          Calcutta     26.491333  26.515167  26.703917  26.561333  26.634333
#          Delhi        26.048333  25.862917  26.634333  25.721083  26.239917
# ...

# %%
pivoit_by_year.loc[('Egypt','Cairo'):('India','Delhi'), "2005":"2010"]
# Out:
# year                       2005       2006       2007       2008       2009  \
# country  city
# Egypt    Cairo        22.006500  22.050000  22.361000  22.644500  22.625000
#          Gizeh        22.006500  22.050000  22.361000  22.644500  22.625000
# Ethiopia Addis Abeba  18.312833  18.427083  18.142583  18.165000  18.765333
# France   Paris        11.552917  11.788500  11.750833  11.278250  11.464083
# Germany  Berlin        9.919083  10.545333  10.883167  10.657750  10.062500
# India    Ahmadabad    26.828083  27.282833  27.511167  27.048500  28.095833
#          Bangalore    25.476500  25.418250  25.464333  25.352583  25.725750
#          Bombay       27.035750  27.381500  27.634667  27.177750  27.844500
#          Calcutta     26.729167  26.986250  26.584583  26.522333  27.153250
#          Delhi        25.716083  26.365917  26.145667  25.675000  26.554250
#
# year                       2010
# country  city
# Egypt    Cairo        23.718250
#          Gizeh        23.718250
# ...

# %%
pivot_mean=pivoit_by_year.mean()
pivot_mean[pivot_mean==pivot_mean.max()]
# Out:
# year
# 2013    20.312285
# dtype: float64

# %%
display(pivoit_by_year.head())
city_col=pivoit_by_year.mean(axis=1) 
display(city_col)
# Out:
# year                        2000       2001       2002       2003       2004  \
# country     city
# Afghanistan Kabul      15.822667  15.847917  15.714583  15.132583  16.128417
# Angola      Luanda     24.410333  24.427083  24.790917  24.867167  24.216167
# Australia   Melbourne  14.320083  14.180000  14.075833  13.985583  13.742083
#             Sydney     17.567417  17.854500  17.733833  17.592333  17.869667
# Bangladesh  Dhaka      25.905250  25.931250  26.095000  25.927417  26.136083
#
# year                        2005       2006       2007       2008       2009  \
# country     city
# Afghanistan Kabul      14.847500  15.798500  15.518000  15.479250  15.093333
# Angola      Luanda     24.414583  24.138417  24.241583  24.266333  24.325083
# Australia   Melbourne  14.378500  13.991083  14.991833  14.110583  14.647417
#             Sydney     18.028083  17.749500  18.020833  17.321083  18.175833
# Bangladesh  Dhaka      26.193333  26.440417  25.951333  26.004500  26.535583
#
# ...

# %%
city_col[city_col==city_col.min()]
# Out:
# country  city
# China    Harbin    4.876551
# dtype: float64

# %% [markdown]
# # CHAPTER 4
